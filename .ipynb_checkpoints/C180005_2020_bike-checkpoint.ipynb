# %% [markdown]
# # 機械学習・データ分析(2019) 学年末卒業課題
#
# ## 課題提出期限
# #### 2020年2月10日（月）10時40分
#
# ## 課題タイトル
# #### Bike Sharing Demandによるバイク貸出数の分析と予測
#
# ## 課題実施方法
# #### 配布されたjupyter notebookに基づいて，Pythonプログラムにより分析と予測を実施し，その結果と結論とを同じjupyter notebookに記載して，ファイル名を学籍番号_2020_bike.ipynbとして，sugimura@ccg.ac.jpへメール添付ファイルとして送信
#
# ## 課題説明
# 1. 配布jupyter notebook中の解説・コードを読んで，bike貸出数の分析と予測を行う手法・手順を理解する．
# 1. 配布資料に記載されている分析及び予測は，不十分な例であるため，分析及び予測の精度を高めるための方針を決める．
# 1. 方針にしたがって，分析プログラムと予測モデルを変更し，結果を評価する．
# 1. 方針，分析結果，予測の結果をjupyter notebookに記載する．
# 1. 満足できる結果が得られたならば，課題終了．もし，予測結果を高めるための工夫の余地があるならば，新たな方針を立てて，4.に戻る．
# 1. 結論をまとめて，jupyter notebookのファイル名を学籍番号_2020_bike.ipynbとして，sugimura@ccg.ac.jpへ送信する．
#
# ## 評価のポイント
# + 提出期限内に提出できているかどうか（40点）
# + 分析・予測モデル構築・評価の手法について理解できているか（30点）
# + 分析・予測モデル構築・評価を論理的に行っているか（たとえば，適切な分析を行っているか，分析の結果が予測モデルに反映しているか，予測結果と結論が合理的であるか）(30点）
#
# ## 2020年1月26日までに課題提出済みの方へ
# + 2020年1月20日時点でお知らせした内容にしたがって課題が提出されていれば，再提出の必要はありません．ただし，再提出しても構いません．
# + 再提出しない場合であっても，課題は実施してください．
#
# ## Google Colaboratoryの使用について
# + 配布したコードでは，モデル構築の際に機械学習を行います．Microsoft Azure Notebookを使った場合，学習終了まで数分を要することがあります．
# + 学習時間を短縮するために，Google Colaboratoryを用いることも可能です．Google Colaboratory用のjupyter notebookも同時に配布します．
# + Google Colaboratory版では，Google Driveを使うための特別なコードを挿入しています．

# %% [markdown]
# # Bike Sharing Demand
#
# ### 以下の作業を行います
#
# #### ①2年間(2011-2012)の，1時間ごとのレンタル自転車の貸出数と，気象データ等が記録されたデータファイルを読み込む
# #### ②貸出数に影響を与えるパラメータ（貸出数との相関が大きいパラメータ）を見つける
# #### ③見つけ出したパラメータを使って貸出数を予測するモデルを構築する
# #### ④モデルの予測性能を評価する

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
import statsmodels.formula.api as sm

from IPython.display import Image, display

# %% [markdown]
# ### データ読み込み

# %%
df = pd.read_csv('bike.csv')
df.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
df.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %% [markdown]
# ### 時刻データを年，月，日，曜日，時刻に分割

# %%
# year, month, day, day of week, time
df['datetimeobj'] = pd.to_datetime(df['datetime'])
df['year'] = df['datetimeobj'].dt.year
df['month'] = df['datetimeobj'].dt.month
df['day'] = df['datetimeobj'].dt.day
df['dayofweek'] = df['datetimeobj'].dt.dayofweek
df['hour'] = df['datetimeobj'].dt.hour

# print(df[350:400])
df.head(10)
# df.tail(10)
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1   9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1   9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1   9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1   9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1   9.84  14.395
# 5  2011-01-01 05:00:00       1        0           0        2   9.84  12.880
# 6  2011-01-01 06:00:00       1        0           0        1   9.02  13.635
# 7  2011-01-01 07:00:00       1        0           0        1   8.20  12.880
# 8  2011-01-01 08:00:00       1        0           0        1   9.84  14.395
# 9  2011-01-01 09:00:00       1        0           0        1  13.12  17.425
#
#    humidity  windspeed  casual  registered  count         datetimeobj  year  \
# 0        81     0.0000       3          13     16 2011-01-01 00:00:00  2011
# 1        80     0.0000       8          32     40 2011-01-01 01:00:00  2011
# 2        80     0.0000       5          27     32 2011-01-01 02:00:00  2011
# 3        75     0.0000       3          10     13 2011-01-01 03:00:00  2011
# 4        75     0.0000       0           1      1 2011-01-01 04:00:00  2011
# 5        75     6.0032       0           1      1 2011-01-01 05:00:00  2011
# 6        80     0.0000       2           0      2 2011-01-01 06:00:00  2011
# 7        86     0.0000       1           2      3 2011-01-01 07:00:00  2011
# 8        75     0.0000       1           7      8 2011-01-01 08:00:00  2011
# 9        76     0.0000       8           6     14 2011-01-01 09:00:00  2011
#
#    month  day  dayofweek  hour
# 0      1    1          5     0
# 1      1    1          5     1
# 2      1    1          5     2
# 3      1    1          5     3
# 4      1    1          5     4
# 5      1    1          5     5
# 6      1    1          5     6
# 7      1    1          5     7
# 8      1    1          5     8
# 9      1    1          5     9

# %% [markdown]
# ### 貸出数の推移を確認

# %%
df.plot(x='datetime', y='count')

# %% [markdown]
# #### 2011年より2012年の方が貸出数増加
# #### 1〜3月（春）の貸出数が少ない

# %% [markdown]
# ### 月ごとの貸出数

# %%
# 表示に時間を要するのでコメントアウトした！
#plt.figure()
#df.groupby('month')['count'].plot(kind='bar')
Image('monthly_counts.png')

# %% [markdown]
# #### 1日単位でグラフ表示をしても傾向を把握できない

# %% [markdown]
# ### （ヒント）　月ごとに，その月の毎日の貸出数の平均をグラフ化する
# #### 以下のコードのA，Bに適当な変数名を入れると，貸出数の平均をグラフ化できる

# %%
plt.figure()
df.groupby('month')['count'].mean().plot(kind='bar')

# %% [markdown]
# #### （ヒント）月ごとの貸出数に特徴はあるか？

# %% [markdown]
# ### （ヒント）季節ごとの貸出数に特徴はあるか？

# %%
plt.figure()
df.groupby('season')['count'].mean().plot(kind='bar')

# %% [markdown]
# #### 季節ごとの特徴は？

# %% [markdown]
# #### 相関関係有り

# %% [markdown]
# ### (ヒント）日ごとの貸出数（平均）を調べる

# %%
plt.figure()
df.groupby('day')['count'].mean().plot(kind='bar')

# %% [markdown]
# #### 1〜19日までのデータしかないのは，1〜19日がトレーニングデータとして提供され，20日以降がテスト用データとして提供されているためである．

# %% [markdown]
# ### (ヒント)曜日ごとの貸出数（平均）を調べる

# %%
plt.figure()
df.groupby('dayofweek')['count'].mean().plot(kind='bar')

# %% [markdown]
# #### 曜日による差はあるか？

# %% [markdown]
#  #### あまり無い

# %% [markdown]
# ### (ヒント）時刻ごとの貸出数（平均）を調べる

# %%
plt.figure()
df.groupby('hour')['count'].mean().plot(kind='bar')

# %% [markdown]
# #### 深夜帯の貸出数はどうか．朝夕の通勤時間帯の貸出数は？

# %% [markdown]
# #### 相関関係有り　深夜帯-> 少ない, 朝夕の通勤時間帯 -> 多い

# %% [markdown]
# ### (ヒント）休日holiday／非休日における時刻ごとの貸出数（平均）

# %%
holiday_hour = df.groupby(['holiday', 'hour'])['count'].mean()
holiday_hour
# Out:
# holiday  hour
# 0        0        54.796380
#          1        33.582766
#          2        22.747126
#          3        11.738717
#          4         6.377622
#          5        19.961276
#          6        77.357466
#          7       216.119910
#          8       366.703620
#          9       222.088235
#          10      173.461538
#          11      208.787330
#          12      254.693002
#          13      255.774266
#          14      241.164786
#          15      253.169300
#          16      316.417607
#          17      471.722348
#          18      433.392777
#          19      316.306998
#          20      228.792325
#          21      173.121896
#          22      133.347630
#          23       90.009029
# 1        0        66.769231
#          1        43.230769
#          2        28.000000
#          3        12.416667
#          4         7.384615
#          5        13.230769
#          6        38.923077
#          7       111.000000
#          8       229.000000
#          9       211.307692
#          10      230.538462
#          11      274.846154
#          12      318.384615
#          13      326.384615
#          14      321.076923
#          15      292.769231
#          16      314.846154
#          17      368.000000
#          18      344.538462
#          19      280.230769
#          20      219.153846
#          21      181.846154
#          22      141.384615
#          23       72.461538
# Name: count, dtype: float64

# %% [raw]
#     <<== 非休日                  休日==>>

# %%
holiday_hour.plot()

# %% [markdown]
# ### （ヒント）休日における時刻ごとの貸出数（平均）を調べる

# %% [markdown]
# ### 休日

# %%
holiday_hour_1 = df.query('holiday == 1').groupby('hour')['count'].mean()

# %%
holiday_hour_1.plot(kind='bar')

# %% [markdown]
# ### 非休日

# %%
holiday_hour_0 = df.query('holiday == 0').groupby('hour')['count'].mean()

# %%
holiday_hour_0.plot(kind='bar')

# %% [markdown]
# #### （ヒント）グラフ表示

# %%
holiday_hour_2 = df.groupby(['holiday', 'hour'])['count'].mean()
holiday_hour_2
# Out:
# holiday  hour
# 0        0        54.796380
#          1        33.582766
#          2        22.747126
#          3        11.738717
#          4         6.377622
#          5        19.961276
#          6        77.357466
#          7       216.119910
#          8       366.703620
#          9       222.088235
#          10      173.461538
#          11      208.787330
#          12      254.693002
#          13      255.774266
#          14      241.164786
#          15      253.169300
#          16      316.417607
#          17      471.722348
#          18      433.392777
#          19      316.306998
#          20      228.792325
#          21      173.121896
#          22      133.347630
#          23       90.009029
# 1        0        66.769231
#          1        43.230769
#          2        28.000000
#          3        12.416667
#          4         7.384615
#          5        13.230769
#          6        38.923077
#          7       111.000000
#          8       229.000000
#          9       211.307692
#          10      230.538462
#          11      274.846154
#          12      318.384615
#          13      326.384615
#          14      321.076923
#          15      292.769231
#          16      314.846154
#          17      368.000000
#          18      344.538462
#          19      280.230769
#          20      219.153846
#          21      181.846154
#          22      141.384615
#          23       72.461538
# Name: count, dtype: float64

# %%
holiday_hour_2.plot(label='holiday')
plt.legend(fontsize=12)

# %% [markdown]
# ### 上のグラフは、holidayにおける時刻別の貸出数のグラフ
# ### それでは、
# + holiday以外の日における時刻別の貸出数
# + workingdayにおける時刻別の貸出数
# + 非workingdayにおける時刻別の貸出数
# ### もグラフ化して、一つのグラフに表示しよう！

# %% [markdown]
# #### （ヒント）workingday, holiday, non-working day, non-holidayに貸出数の特徴はあるか？

# %% [markdown]
# ### workingday

# %%
workingday = df.query('workingday == 1').groupby('hour')['count'].mean()

# %%
workingday.plot(kind='bar')

# %% [markdown]
# ### holiday

# %%
holiday = df.query('holiday == 1').groupby('hour')['count'].mean()

# %%
holiday.plot(kind='bar')

# %% [markdown]
# ### non-working day

# %%
non_workingday = df.query('workingday == 0').groupby('hour')['count'].mean()

# %%
non_workingday.plot(kind='bar')

# %% [markdown]
# ### non-holiday

# %%
non_holiday = df.query('holiday == 0').groupby('hour')['count'].mean()

# %%
non_holiday.plot(kind='bar')

# %%
plt.figure()

workingday.plot(label='workingday')
holiday.plot(label='holiday')
non_workingday.plot(label='non_workingday')
non_holiday.plot(label='non_holiday')

plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=12)

# %% [markdown]
# ### (ヒント）季節による貸出数の時刻変化も調べてみよう
#
# #### 春はseason = 1, 夏はseason = 2, 秋はseason =3 ,冬はseason=4とする．

# %%
df.groupby(['season', 'hour'])['count'].mean().plot();

# %%
season_1 = df.query('season == 1').groupby('hour')['count'].mean()

# %%
season_1.plot();

# %%
season_2 = df.query('season == 2').groupby('hour')['count'].mean()

# %%
season_2.plot();

# %%
season_3 = df.query('season == 3').groupby('hour')['count'].mean()

# %%
season_3.plot();

# %%
season_4 = df.query('season == 4').groupby('hour')['count'].mean()

# %%
season_4 .plot();

# %%
plt.figure()
season_1.plot(label='season_1')
season_2.plot(label='season_2')
season_3.plot(label='season_3')
season_4.plot(label='season_4')
pass
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=12)

# %% [markdown]
# #### (ヒント）季節によって時間帯ごとの貸出数に差はあるか？貸出数が少ない季節はあるか？

# %% [markdown]
# ### season1は深夜から早朝を除き、時間帯ごとの貸出数が少なく、全体の貸出数が少ない。 時間帯ごとの貸出数の傾向は似ている。

# %% [markdown]
# ### 天候による貸出数の差異（合計）を調べる

# %%
df.groupby('weather')['count'].sum().plot(kind='bar')

# %% [markdown]
# １・・・晴れ　　２・・・曇り　　３・・・雨　　４・・・大雨

# %% [markdown]
# ### （ヒント）天候による貸出数の差異（平均）を調べる

# %%
df.groupby('weather')['count'].mean().plot(kind='bar')

# %% [markdown]
# #### （ヒント）大雨の日に貸出数（平均）が大きいが，大雨の日は1日しかなく，平均をとる意味がないので，大雨の日は無視する．

# %% [markdown]
# ### 天候毎の貸出数の時間変化（平均）を調べる

# %%
df.query('weather == 1').groupby('hour')['count'].mean().plot(label='fine')
df.query('weather == 2').groupby('hour')['count'].mean().plot(label='cloudy')
df.query('weather == 3').groupby('hour')['count'].mean().plot(label='rainy')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=12)

# %% [markdown]
# #### 天候によって時間帯ごとの貸出数の傾向は変わらない．ただし，雨の日の貸出数は少ない．

# %% [markdown]
# ### （ヒント）気温，体感温度，湿度，風速との関係を調べる

# %%
# 気温と体感温度との関係
plt.figure()
df.plot(x='temp', y='atemp', kind='scatter')

# %% [markdown]
# #### (ヒント）気温と体感温度を散布図にプロットすると、ほぼ直線上に並んでいる．
#
# #### 気温と体感温度との間にはどのような関係があるか？

# %% [markdown]
# ### 正の相関がある

# %%
#import seaborn as sns
# 温度，体感温度，湿度，風速，貸出数の関係
plt.figure()
sns.pairplot(data=df[['temp', 'atemp', 'humidity', 'windspeed', 'count']]) # 対角線はヒストグラム

# %% [markdown]
# #### Seabornを使うと、各要素の分布ヒストグラムとすべての要素の組み合わせの散布図とを表示できる。
#
# #### 散布図から何が読み取れるか？

# %% [markdown]
# ### 気温と体感温度には正の相関が有り、他の変量は無相関と言える

# %%
# 相関係数をヒートマップで表示
plt.figure(figsize=(9,6))
# plt.figure()

sns.heatmap(df[['temp', 'atemp', 'humidity', 'windspeed', 'count']].corr())

# %% [markdown]
# #### ヒートマップも表示した．
#
# #### 温度，体感温度，湿度，風速と貸出数との間にどのような関係があるか？

# %% [markdown]
# ### 温度=体感温度>風速>湿度 の順に相関がある

# %% [markdown]
# ### （ヒント）会員か非会員かによる時刻ごとの貸出台数の違いを調べよう

# %% [markdown]
# ### 会員

# %%
registered = df.groupby('hour')['registered'].mean()

# %%
registered.plot(kind='bar')

# %% [markdown]
# ### 非会員

# %%
casual = df.groupby('hour')['casual'].mean()

# %%
casual.plot(kind='bar');

# %%
casual.plot(label='casual')
registered.plot(label='registered')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=12)

# %% [markdown]
# #### (ヒント）会員と非会員とを分けて調べると，貸出数にどのような特徴があるか？

# %% [markdown]
# ### 朝、夕の通勤時間帯は会員による貸出が突出している

# %% [markdown]
# ### （ヒント）会員／非会員、平日／土日・祝日による貸出数の違いを調べよう
# #### 会員＆workingday，会員＆non-working day，非会員＆workingday，非会員&non-working dayの4つの場合について貸出数の特徴を調べる

# %% [markdown]
# ### 会員＆workingday

# %%
registered_workingday = df.query('workingday == 1').groupby('hour')['registered'].mean()

# %%
registered_workingday.plot();

# %% [markdown]
# ### 会員＆non-working day

# %%
registered_non_workingday = df.query('workingday == 0').groupby('hour')['registered'].mean()

# %%
registered_non_workingday.plot();

# %% [markdown]
# ### 非会員＆workingday

# %%
casual_workingday = df.query('workingday == 1').groupby('hour')['casual'].mean()

# %%
casual_workingday.plot();

# %% [markdown]
# ### 非会員&non-working day

# %%
casual_non_workingday = df.query('workingday == 0').groupby('hour')['casual'].mean()

# %%
casual_non_workingday.plot();

# %% [markdown]
# #### （ヒント）非会員は（？）の貸出数が多い。 ==>> 日中
# #### （ヒント）会員は（？）の貸出数の方が多い。 ==>> 平日は朝夕の通勤時間帯、土日・祝日は日中

# %% [markdown]
# ### （ヒント)　直前のセルで調べた4通りの条件に関して，時刻ごとの貸出数を調べよう

# %% [markdown]
# #### (ヒント）たとえば，次のようなグラフを描くことができる．

# %%
Image('working_nonworking.png')

# %%
registered_workingday.plot(label='registered_workingday')
registered_non_workingday.plot(label='registered_non_workingday')
casual_workingday.plot(label='casual_workingday')
casual_non_workingday.plot(label='casual_non_workingday')
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0, fontsize=12)

# %% [markdown]
# #### このグラフから分かることは？

# %% [markdown]
# ### 平日の会員による貸出はその他の条件と傾向が異なっている(朝夕の通勤時間帯の貸出数が突出している)

# %% [markdown]
# ### データ分析まとめ
#
# 以上の分析から，たとえば，以下の特徴を見つけることができる．？部分は各自で見つけること．
#
# + 2011年に比べて2012年は？  ==>> 貸出数が増加している
# + 春（1〜3月）に？　==>> 貸出数が少なくなる
# + 日による差は？ ==>> 顕著な差は見られない
# + 曜日による差は？ ==>> 顕著な差は見られない
# + 平日には？にレンタル数が多い  ==>> 朝夕の通勤時間帯
# + 休日には？にレンタル数が多い  ==>> 日中
# + 雨の日の貸出数は？（大雨の日のデータは？）==>> 少ない　(ただし大雨の日のデータを除く)
# + 温度，体感温度は？ ==>>  互いに正の相関がある。レンタル数に対する影響が大きい
# + 湿度，風速は，レンタル数に？　==>> 余り影響しない
# + 非会員は．？にレンタル数が多い  ==>> 日中
# + 会員は，？にレンタル数が多い  ==>> 平日は朝夕の通勤時間帯、土日・祝日は日中。特に平日朝夕が多い。

# %% [markdown]
# ## 回帰分析
#
# 回帰分析は，目的変数と説明変数との間の関係性を求める分析手法である．まず最初に，説明変数が1個である単回帰分析を行う．目的変数と説明変数との関係を求めることによって，説明変数から目的変数の値を予測することができる．
#
# 目的変数$y$が，$y = a*x + b$の関係式で表される場合に，$a$と$b$を求める手法が回帰分析である．

# %% [markdown]
# ### 目的変数$y$をcountとし，説明変数$x$をmonthとした場合の回帰分析は以下のとおりである．

# %%
#from sklearn.model_selection import train_test_split
#from sklearn.linear_model import LinearRegression
#import statsmodels.formula.api as sm


# 説明変数と目的変数
X = df.loc[:, ['month']].values
y = df.loc[:, ['count']].values

# トレーニングデータとテストデータとの分離
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# 回帰分析(最小二乗法による回帰分析)
model = sm.ols(formula = 'count ~ month', data = df)

# 回帰分析を実行
result = model.fit()

# 分析結果
print(result.summary())
print(result.params['Intercept'])
print(result.params['month'])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.028
# Model:                            OLS   Adj. R-squared:                  0.028
# Method:                 Least Squares   F-statistic:                     311.7
# Date:                Wed, 05 Feb 2020   Prob (F-statistic):           8.34e-69
# Time:                        17:05:29   Log-Likelihood:                -71892.
# No. Observations:               10886   AIC:                         1.438e+05
# Df Residuals:                   10884   BIC:                         1.438e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    134.3446      3.666     36.649      0.000     127.159     141.530
# month          8.7755      0.497     17.656      0.000       7.801       9.750
# ==============================================================================
# Omnibus:                     2033.062   Durbin-Watson:                   0.325
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3515.733
# Skew:                           1.219   Prob(JB):                         0.00
# Kurtosis:                       4.345   Cond. No.                         16.0
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 134.34461887163457
# 8.775519825382528

# %% [markdown]
# #### 回帰分析の結果を考察
#
# 回帰分析の結果から，直線の傾きと切片は，それぞれ，<br>
# + 傾き = month = 8.7755
# + 切片 = Intercept = 134.3446 <br>
# であることがわかった．つまり，countとmonthとの関係は，<br>
# $ count = 8.7755 * month + 134.3446 $<br>
# と表すことができる．<br>
#
# OLS Regression Resultsにおけるいくつかの重要なデータについて説明する<br>
# + R-squared: 説明変数がどの程度目的関数を説明しているかを表す決定係数．この値が１に近づくほど，推定した回帰式の当てはまりがよい，と判断する．
# + Adj. R-squared:調整済みの決定係数．決定係数は，サンプル数が少なく，かつ，説明変数の数が多くなる程，1に近づく性質がある．そこで，Adj. R-squaredは，サンプル数と説明変数の数の影響を調整した決定係数である．
# + F-statistic:F統計量．F値が大きい程，回帰モデルが信頼できる．
# + coef:回帰係数(coefficient)．回帰分布により求める値．
# + std err:標準誤差(standard error)．推定料の標準偏差．推定した係数がどの程度のばらつきを持つかという推定量の精度の高さを表す．
# + t:t値．係数を標準誤差で割ったもの．つまり，係数が標準誤差いくつ分であるかを示す．有意水準を5%とする場合，t値の絶対値が2位上であれば，統計学的に優位であることを意味する．
# + P>|t|:P値は，データ分析結果の優位性を示す数値である．この結果が偶然により発生した確率（帰無仮説が成立する確率）を表す．t値が求められれば，P値は自動的に計算できる．有意水準を5%とすると，P値が0.05以下の場合に，帰無仮説が棄却され，統計的に優位である，と解釈できる．
# + 0.025:95%信頼区間の下限値
# + 0.975:95%信頼区間の上限値

# %% [markdown]
# ### 結果をグラフ表示
# #### 回帰分析結果から回帰直線用のデータを生成する

# %%
ax = np.arange(1, 12, 1)
ay = result.params['month'] * ax + result.params['Intercept']

ax2 = df.plot(x = 'month', y = 'count', kind = 'scatter')
ax2.plot(ax, ay, color = 'r')

# %% [markdown]
# 月ごとの貸出数から毎月の貸出数を予測することは難しい！## すなわち１変量での分析は困難

# %% [markdown]
# #### 説明変数を温度として回帰分析を行う

# %%
# 説明変数と目的変数
X = df.loc[:, ['temp']].values
y = df.loc[:, ['count']].values

# トレーニングデータとテストデーtとの分離
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# 回帰分析(最小二乗法による回帰分析)
model = sm.ols(formula = 'count ~ temp', data = df)

# 回帰分析を実行
result = model.fit()

# 分析結果
print(result.summary())
print(result.params['Intercept'])
print(result.params['temp'])
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.156
# Model:                            OLS   Adj. R-squared:                  0.156
# Method:                 Least Squares   F-statistic:                     2006.
# Date:                Wed, 05 Feb 2020   Prob (F-statistic):               0.00
# Time:                        17:05:29   Log-Likelihood:                -71125.
# No. Observations:               10886   AIC:                         1.423e+05
# Df Residuals:                   10884   BIC:                         1.423e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      6.0462      4.439      1.362      0.173      -2.656      14.748
# temp           9.1705      0.205     44.783      0.000       8.769       9.572
# ==============================================================================
# Omnibus:                     1871.687   Durbin-Watson:                   0.369
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3221.966
# Skew:                           1.123   Prob(JB):                         0.00
# Kurtosis:                       4.434   Cond. No.                         60.4
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# 6.04621295961495
# 9.170540481426222

# %%
ax = np.arange(-10, 40, 1)
ay = result.params['temp'] * ax + result.params['Intercept']

ax2 = df.plot(x = 'temp', y = 'count', kind = 'scatter')
ax2.plot(ax, ay, color = 'r')

# %% [markdown]
# #### 温度と貸出数との間には，多少相関関係があるようにも見えるが，温度だけから貸出数を予測することは難しい．

# %% [markdown]
# ## 重回帰分析
#
# 1つの説明変数から目的変数を予測することは難しいことが分かった．そこで，複数の説明変数と目的変数との関係を求める重回帰分析を用いることにする．
#
# 上の例では，説明変数として温度を用いた．ここでは，温度に加えて，時刻を説明変数として用いることにする．

# %% [markdown]
# ### 質的変数をカテゴリ変数に変換
#
# ここで，season, holiday, workingday, year, month, hourなどの質的変数を回帰分析の説明変数として用いるために，これらの質的変数をカテゴリ変数に変換する．

# %% [raw]
# ((量的変数))

# %%
# 質的変数をカテゴリ変数に変換する
for v in ["season","holiday","workingday","weather","month","year","hour"]:
    df[v] = df[v].astype("category")

# %% [markdown]
# #### 温度tempと，時刻hourを説明変数として，重回帰分析を行う．

# %%
model_w = sm.ols(formula="count ~ hour + temp", data=df)
result_w = model_w.fit()
print(result_w.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.594
# Model:                            OLS   Adj. R-squared:                  0.593
# Method:                 Least Squares   F-statistic:                     662.9
# Date:                Wed, 05 Feb 2020   Prob (F-statistic):               0.00
# Time:                        17:05:29   Log-Likelihood:                -67135.
# No. Observations:               10886   AIC:                         1.343e+05
# Df Residuals:                   10861   BIC:                         1.345e+05
# Df Model:                          24
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    -71.9198      6.090    -11.809      0.000     -83.858     -59.982
# hour[T.1]    -18.7832      7.662     -2.451      0.014     -33.803      -3.763
# hour[T.2]    -28.5120      7.688     -3.708      0.000     -43.583     -13.441
# hour[T.3]    -39.5098      7.755     -5.095      0.000     -54.711     -24.308
# hour[T.4]    -42.2030      7.716     -5.470      0.000     -57.327     -27.079
# hour[T.5]    -25.9941      7.674     -3.387      0.001     -41.036     -10.953
# hour[T.6]     31.3578      7.661      4.093      0.000      16.340      46.376
# hour[T.7]    166.1676      7.660     21.692      0.000     151.152     181.183
# hour[T.8]    311.3161      7.659     40.650      0.000     296.304     326.328
# hour[T.9]    164.3294      7.658     21.458      0.000     149.318     179.341
# hour[T.10]   111.2224      7.660     14.519      0.000      96.206     126.238
# hour[T.11]   140.5060      7.665     18.330      0.000     125.481     155.531
# hour[T.12]   181.4003      7.666     23.662      0.000     166.373     196.428
# hour[T.13]   178.0762      7.673     23.209      0.000     163.036     193.116
# hour[T.14]   160.6796      7.678     20.928      0.000     145.630     175.730
# hour[T.15]   170.6336      7.679     22.220      0.000     155.581     185.687
# hour[T.16]   233.8017      7.678     30.453      0.000     218.752     248.851
# hour[T.17]   389.2946      7.672     50.739      0.000     374.255     404.334
# hour[T.18]   355.0421      7.667     46.306      0.000     340.013     370.071
# hour[T.19]   244.4240      7.662     31.902      0.000     229.406     259.442
# hour[T.20]   161.7729      7.658     21.124      0.000     146.762     176.784
# hour[T.21]   110.1830      7.656     14.392      0.000      95.176     125.190
# hour[T.22]    73.4054      7.655      9.590      0.000      58.401      88.410
# hour[T.23]    32.1614      7.654      4.202      0.000      17.158      47.165
# temp           6.6826      0.147     45.590      0.000       6.395       6.970
# ==============================================================================
# Omnibus:                     1059.027   Durbin-Watson:                   0.375
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2283.179
# Skew:                           0.616   Prob(JB):                         0.00
# Kurtosis:                       4.875   Cond. No.                         530.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# #### R-squaredとAdj. R-squaredが共に0.59程度である．
#
# #### (ヒント）これらの値が0.8以上となるような説明変数を見つけたい．
#
# #### （ヒント）workingdayとnon-working dayとでは，貸出のパターンに違いがあった．この2つのパターンを1つのモデルで表現すると，モデルの予測精度が低下する．そこで，workingdayとnon-working dayとで別々のモデルを構築することを考える．

# %% [markdown]
# ### (ヒント）以下の方針でモデルを構築する
# #### workingdayとnon-working dayとは別々のモデル（別々に分析する）なのではないか？と予測

# %% [markdown]
# ### workingday

# %% [markdown]
# #### 説明変数として？を利用する ==>> hour, temp, year, season

# %%
workingday = df.query('workingday == 1')

# %%
# 質的変数をカテゴリ変数に変換する
for v in ["season","holiday","workingday","weather","month","year","hour"]:
    workingday[v] = workingday[v].astype("category")
# Out:
# /home/lubuntu001/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model_w = sm.ols(formula="count ~ hour + temp + year + season ", data=workingday)
result_w = model_w.fit()
print(result_w.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.818
# Model:                            OLS   Adj. R-squared:                  0.817
# Method:                 Least Squares   F-statistic:                     1181.
# Date:                Wed, 05 Feb 2020   Prob (F-statistic):               0.00
# Time:                        17:05:29   Log-Likelihood:                -42886.
# No. Observations:                7412   AIC:                         8.583e+04
# Df Residuals:                    7383   BIC:                         8.603e+04
# Df Model:                          28
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -139.2236      5.358    -25.985      0.000    -149.727    -128.721
# hour[T.1]      -19.0989      6.348     -3.009      0.003     -31.543      -6.655
# hour[T.2]      -26.8934      6.370     -4.222      0.000     -39.380     -14.406
# hour[T.3]      -33.3843      6.460     -5.168      0.000     -46.048     -20.721
# hour[T.4]      -30.5264      6.417     -4.757      0.000     -43.105     -17.948
# hour[T.5]       -5.3916      6.350     -0.849      0.396     -17.839       7.055
# hour[T.6]       73.0113      6.350     11.497      0.000      60.563      85.460
# hour[T.7]      259.5289      6.347     40.888      0.000     247.086     271.971
# hour[T.8]      445.7451      6.344     70.267      0.000     433.310     458.180
# hour[T.9]      203.8520      6.343     32.138      0.000     191.418     216.286
# hour[T.10]      90.8252      6.348     14.307      0.000      78.381     103.269
# hour[T.11]     109.5379      6.360     17.223      0.000      97.070     122.005
# hour[T.12]     148.8819      6.368     23.381      0.000     136.400     161.364
# hour[T.13]     143.3511      6.383     22.457      0.000     130.838     155.864
# hour[T.14]     124.3230      6.396     19.438      0.000     111.785     136.861
# hour[T.15]     141.7001      6.401     22.137      0.000     129.152     154.248
# hour[T.16]     236.2082      6.397     36.925      0.000     223.668     248.748
# hour[T.17]     475.2857      6.384     74.450      0.000     462.771     487.800
# hour[T.18]     444.1620      6.371     69.713      0.000     431.672     456.652
# hour[T.19]     301.5436      6.357     47.434      0.000     289.082     314.005
# hour[T.20]     204.6024      6.348     32.230      0.000     192.158     217.047
# hour[T.21]     142.6815      6.343     22.496      0.000     130.248     155.115
# hour[T.22]      98.6439      6.339     15.561      0.000      86.217     111.071
# hour[T.23]      51.2528      6.338      8.087      0.000      38.829      63.677
# year[T.2012]    95.3972      1.845     51.696      0.000      91.780      99.015
# season[T.2]     44.0301      3.366     13.081      0.000      37.432      50.628
# season[T.3]     39.8908      4.287      9.305      0.000      31.487      48.295
# season[T.4]     61.9454      2.773     22.341      0.000      56.510      67.381
# temp             4.7865      0.209     22.883      0.000       4.376       5.197
# ==============================================================================
# Omnibus:                      630.107   Durbin-Watson:                   0.472
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3617.026
# Skew:                          -0.175   Prob(JB):                         0.00
# Kurtosis:                       6.404   Cond. No.                         534.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %% [markdown]
# ### non-working day

# %% [markdown]
# #### 説明変数として？を利用する ==>> hour, temp, year, day, month, weather

# %%
non_workingday = df.query('workingday == 0')

# %%
# 質的変数をカテゴリ変数に変換する
for v in ["season","holiday","workingday","weather","month","year","hour"]:
    non_workingday[v] = non_workingday[v].astype("category")
# Out:
# /home/lubuntu001/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
model_w = sm.ols(formula="count ~ hour + temp + year + day + month + weather ", data=non_workingday)
result_w = model_w.fit()
print(result_w.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                  count   R-squared:                       0.807
# Model:                            OLS   Adj. R-squared:                  0.805
# Method:                 Least Squares   F-statistic:                     369.1
# Date:                Wed, 05 Feb 2020   Prob (F-statistic):               0.00
# Time:                        17:05:29   Log-Likelihood:                -19985.
# No. Observations:                3474   AIC:                         4.005e+04
# Df Residuals:                    3434   BIC:                         4.030e+04
# Df Model:                          39
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# Intercept     -124.5371      8.875    -14.033      0.000    -141.937    -107.137
# hour[T.1]      -18.0134      9.008     -2.000      0.046     -35.675      -0.351
# hour[T.2]      -35.7669      9.041     -3.956      0.000     -53.494     -18.040
# hour[T.3]      -61.2824      9.030     -6.786      0.000     -78.988     -43.577
# hour[T.4]      -75.5946      9.021     -8.380      0.000     -93.281     -57.908
# hour[T.5]      -76.7955      9.076     -8.461      0.000     -94.590     -59.001
# hour[T.6]      -62.6385      9.030     -6.936      0.000     -80.344     -44.933
# hour[T.7]      -36.0760      9.024     -3.998      0.000     -53.770     -18.382
# hour[T.8]       24.0146      9.012      2.665      0.008       6.346      41.683
# hour[T.9]       83.1741      9.009      9.232      0.000      65.511     100.837
# hour[T.10]     160.0439      9.025     17.733      0.000     142.349     177.739
# hour[T.11]     215.5987      9.056     23.807      0.000     197.842     233.355
# hour[T.12]     263.7864      9.102     28.982      0.000     245.941     281.632
# hour[T.13]     267.9896      9.148     29.295      0.000     250.054     285.926
# hour[T.14]     257.7585      9.191     28.046      0.000     239.739     275.778
# hour[T.15]     254.4432      9.201     27.652      0.000     236.402     272.484
# hour[T.16]     249.7989      9.178     27.216      0.000     231.803     267.794
# hour[T.17]     225.7805      9.160     24.649      0.000     207.822     243.739
# hour[T.18]     180.1505      9.108     19.779      0.000     162.293     198.008
# hour[T.19]     134.7489      9.069     14.858      0.000     116.968     152.530
# hour[T.20]      80.8947      9.049      8.940      0.000      63.154      98.636
# hour[T.21]      48.2068      9.025      5.342      0.000      30.512      65.901
# hour[T.22]      25.6346      9.019      2.842      0.005       7.952      43.318
# hour[T.23]      -2.3598      9.018     -0.262      0.794     -20.041      15.322
# year[T.2012]    79.7968      2.663     29.968      0.000      74.576      85.018
# month[T.2]       7.6136      6.368      1.196      0.232      -4.872      20.099
# month[T.3]      32.8602      6.784      4.844      0.000      19.560      46.161
# month[T.4]      53.9988      6.999      7.715      0.000      40.277      67.721
# month[T.5]      71.6910      8.334      8.603      0.000      55.351      88.031
# month[T.6]      60.4121      9.363      6.452      0.000      42.055      78.769
# month[T.7]      17.2198     10.554      1.632      0.103      -3.473      37.912
# month[T.8]      13.3456     10.224      1.305      0.192      -6.700      33.391
# month[T.9]      54.7721      8.941      6.126      0.000      37.242      72.303
# month[T.10]     86.4969      7.290     11.865      0.000      72.203     100.790
# month[T.11]     81.1063      6.355     12.763      0.000      68.647      93.566
# month[T.12]     67.2885      6.261     10.747      0.000      55.013      79.564
# weather[T.2]   -16.3805      3.081     -5.317      0.000     -22.420     -10.341
# weather[T.3]   -69.0293      5.534    -12.473      0.000     -79.880     -58.179
# weather[T.4] -1.173e-15   3.53e-16     -3.319      0.001   -1.87e-15    -4.8e-16
# temp             6.7904      0.421     16.117      0.000       5.964       7.616
# day              1.3022      0.241      5.407      0.000       0.830       1.774
# ==============================================================================
# Omnibus:                      219.380   Durbin-Watson:                   0.322
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              381.732
# Skew:                           0.479   Prob(JB):                     1.28e-83
# Kurtosis:                       4.311   Cond. No.                     1.06e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.71e-26. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.

# %% [markdown]
# #### 重回帰分析の結果は以下のとおり

# %%
# workingday
Image('regression(workingday).png')

# %%
# non-working day
Image('regression(non-working day).png')

# %% [markdown]
# #### workingdayの場合もnon-working dayの場合もR-squaredが0.8以上となっているので，選択した説明変数が高い精度で目的変数を説明できることがわかった．

# %% [markdown]
# #### そこで，説明変数？を使って貸出数を予測するモデルを構築する
#
# #### モデルには，ランダムフォレストモデルを採用する

# %% [markdown]
# ## ランダムフォレスト
#
# ランダムフォレストは，機械学習のアルゴリズムの1つである．学習用のデータセットをランダムにサンプリングして多数の決定木を作成し，決定木分析を繰り返すことで，作成した多数の決定木の集まり（＝森）を元にして，重ね合わせによって結果を求める方法である．<br>
# 精度と汎用性が高く，扱いやすい手法である，といわれている．

# %%
Image('random_forest_1.png')

# %% [markdown]
# ## ランダムフォレストの特徴
# + 母集団のデータ数が多く変数が多い場合に精度が高くなる
# + 目的変数の割合に偏りがあっても，バランスが保たれる（精度を保ったまま分析できる）
# + 分類に用いる変数の重要度を推定できる
# + ただし，決定過程がブラックボックス化しやすい

# %% [markdown]
# ## 以下のコードは，titanic号のデータにランダムフォレストを適用し，生存者の予測モデルを構築した例である．
#
#
# 【実行結果】
# ランダムフォレスト
# from sklearn.model_selection import train_test_split
# from sklearn.metrics import *
# from sklearn.ensemble import RandomForestClassifier
#
# トレーニングデータとテストデータに分ける
# (train_X, test_X, train_y, test_y) = train_test_split(df_X, df_y, test_size=0.3, random_state=0)
#
# ランダムフォレストモデルを生成
# n_estimators 決定木をいくつ生成するか（デフォルトは10）
# clf0 = RandomForestClassifier(random_state=0, n_estimators=20)
# clf = clf0.fit(train_X, train_y)
#
# 結果検証
# pred = clf.predict(test_X)
# fpr, tpr, thresholds = roc_curve(test_y, pred, pos_label=1)
#
# AUC １に近づくほど良い
# print('AUC:', auc(fpr, tpr))
#
# 正答率
# print('score:', accuracy_score(pred, test_y))

# %% [markdown]
# ## bike sharing demandにランダムフォレストモデルを用いて，バイク貸出数予測モデルを構築する
#
# ### 各自工夫するポイントは，説明変数の選び方である
# ### 回帰分析や重回帰分析の結果に基づいて，目的変数である貸出数を予測するために有効な変数を選ぶ
# ### その他のパラメータは変更しない方がよい

# %%
# ランダムフォレストモデル
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# #### 説明変数として，month, hour, tempを選んだ！ ### 余り良い精度ではない

# %%
# 説明変数（説明変数の選び方がポイント）
df_X = df[['month', 'hour', 'temp']]
# 目的変数
df_y = df['count']

# データセットをトレーニングデータとテストデータとに分ける
train_X, test_X, train_y, test_y = train_test_split(df_X, df_y, test_size = 0.3, random_state = 0)

# ランダムフォレストモデルを生成
# 決定木の数=n_estimators は，10とする
clf0 = RandomForestClassifier(random_state = 0, n_estimators = 10)
clf = clf0.fit(train_X, train_y)

# %%
# 結果検証
pred = clf.predict(test_X)
fpr, tpr, thresholds = roc_curve(test_y, pred, pos_label = 1)

# AUCは，１に近づくほどよい
print('AUC:', auc(fpr, tpr))

# 正答率
print('score:', accuracy_score(pred, test_y))
# Out:
# AUC: 0.06982564065230051
# score: 0.01837109614206981

# %%
# 結果を散布図表示
result = pd.DataFrame(test_y)
result['pred'] = pred
result.plot(x = 'pred', y = 'count', kind = 'scatter')

# %% [markdown]
# ### 予測精度が向上するように，説明変数を選んで，予測モデル構築し，モデルの予測性能を評価してください．

# %% [markdown]
# #### 説明変数として、hour, temp, year, season, holidayを選んだ

# %%
# 説明変数（説明変数の選び方がポイント）
df_X = df[[ 'hour', 'temp', 'year','season', 'holiday']]

# 目的変数
df_y = df['count']

# データセットをトレーニングデータとテストデータとに分ける
train_X, test_X, train_y, test_y = train_test_split(df_X, df_y, test_size = 0.3, random_state = 0)

# ランダムフォレストモデルを生成
# 決定木の数=n_estimators は，10とする
clf0 = RandomForestClassifier(random_state = 0, n_estimators = 10)
clf = clf0.fit(train_X, train_y)

# %%
# 結果検証
pred = clf.predict(test_X)
fpr, tpr, thresholds = roc_curve(test_y, pred, pos_label = 1)

# AUCは，１に近づくほどよい
print('AUC:', auc(fpr, tpr))

# 正答率
print('score:', accuracy_score(pred, test_y))
# Out:
# AUC: 0.08874490390215492
# score: 0.018677281077770974

# %%
# 結果を散布図表示
result = pd.DataFrame(test_y)
result['pred'] = pred
result.plot(x = 'pred', y = 'count', kind = 'scatter')

# %% [markdown]
# ## 結論

# %% [markdown]
#  ### 予測精度を向上させることができた。

# %% [markdown]
# ### 説明変数を増やしてモデルを構築することにより、変数が多い場合に精度が高くなるランダムフォレストの特徴が表れている。

# %% [markdown]
# ### ただし、説明変数が多くなると、因果関係を説明するのが困難である。（決定過程のブラックボックス化）
